# %%
import numpy as np
Data = np.load('experiment_results_2.npy')
Columns = ['difficult_level',
           'conflicts_number',
           'decisions_number',
           'fixed_variables',
           'learned_literals',
           'deleted_literals',
           'propogations',
           'visits_number',
           'variables_used',
           'run_time_number']
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
X = np.arange(0, 9)
visits_mean = [Data[Data[:,Columns.index('difficult_level')] == x][:, Columns.index('visits_number')].mean() for x in X]
fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
ax.plot(X, visits_mean, 'r', label='Mean')

visits_variance = [np.var(Data[Data[:,Columns.index('difficult_level')] == x][:,Columns.index('visits_number')]) for x in X]
ax.plot(X, visits_variance, 'b', label='Variance')
ax.set_yscale('log')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.set_size_inches(10.5, 10.5)
plt.xlabel('Difficulty level')
plt.show()

# %%
# Visits
num_bins = 50

colors = ['green', 'red', 'blue', 'yellow', 'pink', 'orange', 'cyan', 'magenta']
fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(0, 4):
    x = Data[Data[:,0] == i][:,7]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

pylab.xlim([0, 3000])
plt.xlabel('Visits')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.set_size_inches(10.5, 10.5)

fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(5, 9):
    x = Data[Data[:,0] == i][:,7]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.set_size_inches(10.5, 10.5)
pylab.xlim([0,30000])
plt.xlabel('Visits')
plt.show()

# %%
# Fixed variables
fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(0, 9):
    x = Data[Data[:,0] == i][:,3]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.set_size_inches(10.5, 14.5)
plt.xlabel('Fixed variables')
plt.show()

# %%
# Learned literals
fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(0, 9):
    x = Data[Data[:,0] == i][:,4]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.set_size_inches(10.5, 14.5)
plt.xlabel('Learned literals')
plt.show()

# %%
# Propogations
fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(4, -1, -1):
    x = Data[Data[:,0] == i][:,6]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
pylab.xlim([0,1500])
plt.xlabel('Propagations')
fig.set_size_inches(10.5, 14.5)

plt.show()

fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(8, 3, -1):
    x = Data[Data[:,0] == i][:,6]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
pylab.xlim([0,7500])
plt.xlabel('Propagations')
fig.set_size_inches(10.5, 14.5)

plt.show()
