# %%
import numpy as np
Data = np.load('experiment_results_2.npy')
"""
Columns
[difficult_level,
conflicts_number,
decisions_number,
fixed_variables,
learned_literals,
deleted_literals,
propogations,
visits_number,
variables_used,
run_time_number]
"""
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
number_of_items_per_level = [len(Data[Data[:,0] == i]) for i in range(9)]


import matplotlib.pyplot as plt
fig, ax = plt.subplots()

ind = np.arange(9)
width = 0.35

rects1 = ax.bar(ind, number_of_items_per_level, width, color='r')

plt.show()

# %%
X = np.arange(0, 9)
visits_mean = [Data[Data[:,0] == x][:,7].mean() for x in X]
plt.plot(X, visits_mean, '')
plt.show()

# %%
X = np.arange(0, 9)
visits_variance = [np.var(Data[Data[:,0] == x][:,7]) for x in X]
plt.plot(X, visits_variance, '')
plt.show()

# %%
Data[Data[:,0] == 3][:,7]
# Out:
# array([  975.,  1539.,   949., ...,   917.,  1546.,  1986.])

# %%
X = Data[:,0]
visits = Data[:,7]
plt.plot(X, visits, '*')
plt.show()

# %%
# Visits
num_bins = 50

colors = ['green', 'red', 'blue', 'yellow', 'pink', 'orange', 'cyan', 'magenta']
fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(0, 4):
    x = Data[Data[:,0] == i][:,7]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

pylab.xlim([0, 3000])
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.set_size_inches(18.5, 10.5)

fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(5, 8):
    x = Data[Data[:,0] == i][:,7]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.set_size_inches(18.5, 10.5)

plt.show()

# %%
# Fixed variables
fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(0, 9):
    x = Data[Data[:,0] == i][:,3]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.set_size_inches(18.5, 10.5)

plt.show()

# %%
# Learned literals
fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(0, 8):
    x = Data[Data[:,0] == i][:,4]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.set_size_inches(18.5, 10.5)

plt.show()

# %%
# Propogations
fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(0, 4):
    x = Data[Data[:,0] == i][:,6]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.set_size_inches(18.5, 10.5)

plt.show()

fig = pyplot.figure()
ax = fig.add_subplot(2,1,1)
for i in range(5, 9):
    x = Data[Data[:,0] == i][:,6]
    n, bins, patches = plt.hist(x, num_bins, normed=1, facecolor=colors[i%len(colors)], alpha=0.5, label='Level ' + str(i))

plt.subplots_adjust(left=0.15)

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
fig.set_size_inches(18.5, 10.5)

plt.show()
